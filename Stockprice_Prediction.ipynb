# %% [markdown]
# <a href="https://colab.research.google.com/github/Naushil7/Stock_Price_Analysis/blob/main/Stockprice_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/8_project/Updated_NIFTY_2.0.csv")
df.head()
# Out:
#          date  Time(h)  Time(m)    close     high      low     open      slot  \
# 0  09-01-2015      9.0     15.0  8301.00  8303.00  8285.45  8285.45  09:15-25
# 1  09-01-2015      9.0     25.0  8288.50  8302.55  8280.65  8301.65  09:25-35
# 2  09-01-2015      9.0     35.0  8285.55  8290.45  8277.40  8289.10  09:35-45
# 3  09-01-2015      9.0     45.0  8276.25  8287.65  8273.95  8285.40  09:45-55
# 4  09-01-2015      9.0     55.0  8285.50  8287.35  8275.05  8275.95  09:55-05
#
#    peak-close intensity  peak-close intensity(%)  ...  open-peak intensity(%)  \
# 0                 -2.00                -0.024088  ...                0.211817
# 1                -14.05                -0.169225  ...                0.010841
# 2                 -4.90                -0.059104  ...                0.016286
# 3                -11.40                -0.137554  ...                0.027156
# 4                 -1.85                -0.022323  ...                0.137749
#
# ...

# %%
df.isnull().sum()
# Out:
# date                       2
# Time(h)                    2
# Time(m)                    2
# close                      2
# high                       2
# low                        2
# open                       2
# slot                       2
# peak-close intensity       2
# peak-close intensity(%)    2
# open-peak intensity        2
# open-peak intensity(%)     2
# open-close change          2
# open-close change(%)       2
# peak-loss volatility       2
# peak-loss volatility(%)    2
# weekday                    2
# day                        2
# month                      2
# year                       2
# GRAPH TYPE                 2
# dtype: int64

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('/content/drive/MyDrive/8_project/Updated_NIFTY_2.0.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot(style='k.')
pyplot.show()

# %%
import plotly.graph_objects as go
# oc = ['open','close']
fig = go.Figure([go.Scatter(x=df['date'], y=df['high'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# df[["day", "month", "year"]] = df["date"].str.split("-", expand = True)
# print(df)

# %%
#unnamed 16 ignore
df.head()
# Out:
#          date  Time(h)  Time(m)    close     high      low     open      slot  \
# 0  09-01-2015      9.0     15.0  8301.00  8303.00  8285.45  8285.45  09:15-25
# 1  09-01-2015      9.0     25.0  8288.50  8302.55  8280.65  8301.65  09:25-35
# 2  09-01-2015      9.0     35.0  8285.55  8290.45  8277.40  8289.10  09:35-45
# 3  09-01-2015      9.0     45.0  8276.25  8287.65  8273.95  8285.40  09:45-55
# 4  09-01-2015      9.0     55.0  8285.50  8287.35  8275.05  8275.95  09:55-05
#
#    peak-close intensity  peak-close intensity(%)  ...  open-peak intensity(%)  \
# 0                 -2.00                -0.024088  ...                0.211817
# 1                -14.05                -0.169225  ...                0.010841
# 2                 -4.90                -0.059104  ...                0.016286
# 3                -11.40                -0.137554  ...                0.027156
# 4                 -1.85                -0.022323  ...                0.137749
#
# ...

# %%
# df.to_csv("/content/drive/MyDrive/8_project/Updated_NIFTY.csv",index=False)
